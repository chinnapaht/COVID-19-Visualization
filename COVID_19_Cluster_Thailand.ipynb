# %% [markdown]
# <a href="https://colab.research.google.com/github/chinnapaht/COVID-19-Visualization/blob/master/COVID_19_Cluster_Thailand.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import altair as alt
import numpy as np

# %%
url='https://data.go.th/dataset/8a956917-436d-4afd-a2d4-59e4dd8e906e/resource/93f74e67-6f76-4b25-8f5d-b485083100b6/download/covid-19-daily.xlsx' #read data of all patients
df=pd.read_excel(url,na_values=['ไม่ระบุ','-','ไม่ทราบ'])
df["age"]=["วัยเด็ก" if i <= 10 else "วัยรุ่น" if i<=20 else "วัยทำงาน" if i<=60 else "ผู้สูงอายุ" for i in df["age"]] 
df['count_value']=[1 for i in range(len(df['no']))]
df[df["Announce Date"] =="2020-03-12"] #look what is start index for 2020-03-12
# Out:
#     no       age   sex  ... Province of onset District of onset count_value
# 59  60  วัยทำงาน  หญิง  ...               กทม               NaN           1
# 60  61  วัยทำงาน   ชาย  ...               กทม               NaN           1
# 61  62  วัยทำงาน  หญิง  ...               กทม               NaN           1
# 62  63  วัยทำงาน   ชาย  ...               กทม               NaN           1
# 63  64  วัยทำงาน  หญิง  ...               กทม               NaN           1
# 64  65  วัยทำงาน  หญิง  ...               กทม               NaN           1
# 65  66  วัยทำงาน  หญิง  ...               กทม               NaN           1
# 66  67  วัยทำงาน  หญิง  ...               กทม               NaN           1
# 67  68  วัยทำงาน   ชาย  ...               กทม               NaN           1
# 68  69  วัยทำงาน  หญิง  ...               กทม               NaN           1
# 69  70  วัยทำงาน  หญิง  ...               กทม               NaN           1
# 70  71  วัยทำงาน  หญิง  ...               กทม               NaN           1
# 71  72  วัยทำงาน   ชาย  ...               กทม           บางกะปิ           1
#
# [13 rows x 10 columns]

# %%
df[df["Announce Date"] =="2020-04-03"] #look what is end index for 2020-04-03
# Out:
#         no         age   sex  ... Province of onset District of onset count_value
# 1875  1876  ผู้สูงอายุ  หญิง  ...               กทม              สาทร           1
# 1876  1877    วัยทำงาน   ชาย  ...            ภูเก็ต             เมือง           1
# 1877  1878    วัยทำงาน  หญิง  ...           นนทบุรี             เมือง           1
# 1878  1879  ผู้สูงอายุ   ชาย  ...               NaN               NaN           1
# 1879  1880    วัยทำงาน  หญิง  ...               NaN               NaN           1
# ...    ...         ...   ...  ...               ...               ...         ...
# 1973  1974    วัยทำงาน   NaN  ...               กทม               NaN           1
# 1974  1975    วัยทำงาน   ชาย  ...               กทม               NaN           1
# 1975  1976    วัยทำงาน  หญิง  ...               กทม           บางซื่อ           1
# 1976  1977    วัยทำงาน  หญิง  ...               NaN               NaN           1
# 1977  1978    วัยทำงาน   ชาย  ...           นนทบุรี          ปากเกร็ด           1
#
# [103 rows x 10 columns]

# %%
df_new=df.iloc[59:1978]
df_new #select only 2020-03-12 - 2020-04-03
# Out:
#         no       age   sex  ... Province of onset District of onset count_value
# 59      60  วัยทำงาน  หญิง  ...               กทม               NaN           1
# 60      61  วัยทำงาน   ชาย  ...               กทม               NaN           1
# 61      62  วัยทำงาน  หญิง  ...               กทม               NaN           1
# 62      63  วัยทำงาน   ชาย  ...               กทม               NaN           1
# 63      64  วัยทำงาน  หญิง  ...               กทม               NaN           1
# ...    ...       ...   ...  ...               ...               ...         ...
# 1973  1974  วัยทำงาน   NaN  ...               กทม               NaN           1
# 1974  1975  วัยทำงาน   ชาย  ...               กทม               NaN           1
# 1975  1976  วัยทำงาน  หญิง  ...               กทม           บางซื่อ           1
# 1976  1977  วัยทำงาน  หญิง  ...               NaN               NaN           1
# 1977  1978  วัยทำงาน   ชาย  ...           นนทบุรี          ปากเกร็ด           1
#
# [1919 rows x 10 columns]

# %%
x=df_new.groupby("Announce Date").count()["no"]
count_all=np.array(x)
# Out:
# 1919

# %%
url_2 ="https://github.com/chinnapaht/COVID-19-Visualization/blob/master/Covid-19-Clusters-Thailand-acc%20.csv" # read cluster data in thailand
df_2=pd.read_html(url_2)[0]
df_2
# Out:
#      Unnamed: 0         วัน  ... Unnamed: 4  Unnamed: 5
# 0           NaN  2020-03-12  ...        NaN         NaN
# 1           NaN  2020-03-12  ...        NaN         NaN
# 2           NaN  2020-03-12  ...        NaN         NaN
# 3           NaN  2020-03-12  ...        NaN         NaN
# 4           NaN  2020-03-12  ...        NaN         NaN
# ..          ...         ...  ...        ...         ...
# 225         NaN  2020-04-03  ...        NaN         NaN
# 226         NaN  2020-04-03  ...        NaN         NaN
# 227         NaN  2020-04-03  ...        NaN         NaN
# 228         NaN  2020-04-03  ...        NaN         NaN
# 229         NaN  2020-04-03  ...        NaN         NaN
#
# [230 rows x 6 columns]

# %%
df_3=df_2.groupby("สถานที่").sum()
x=np.array(df_3["จำนวนผู้ป่วยในแต่ละวัน"])
df_3["percent"]= np.around((x/sum(count_all))*100)
df_3["สถานที่"]=df_3.index
df_3
# Out:
#                                    Unnamed: 0  ...                            สถานที่
# สถานที่                                        ...
# บุคลากรการแพทย์                           0.0  ...                    บุคลากรการแพทย์
# สถานบันเทิง                               0.0  ...                        สถานบันเทิง
# สนามมวย                                   0.0  ...                            สนามมวย
# สัมผัสกับผู้ป่วยที่มีรายงานมาแล้ว         0.0  ...  สัมผัสกับผู้ป่วยที่มีรายงานมาแล้ว
# สัมผัสผู้ที่เดินทางมาจาก ตปท.             0.0  ...      สัมผัสผู้ที่เดินทางมาจาก ตปท.
# อาชีพเสี่ยง                               0.0  ...                        อาชีพเสี่ยง
# เดินทางมาจากต่างประเทศ                    0.0  ...             เดินทางมาจากต่างประเทศ
# แสวงบุญมาเลเซีย                           0.0  ...                    แสวงบุญมาเลเซีย
# แสวงบุญอินโดนีเซีย                        0.0  ...                 แสวงบุญอินโดนีเซีย
# ไปสถานที่ชุมชน                            0.0  ...                     ไปสถานที่ชุมชน
#
# [10 rows x 6 columns]

# %%
selection = alt.selection_multi(fields=['สถานที่'], bind='legend')

chart1=alt.Chart(df_2).mark_area().encode(
    x="วัน:O",
    y='จำนวนผู้ป่วยในแต่ละวัน',
    color=alt.Color('สถานที่:N', scale=alt.Scale(scheme='tableau20')),tooltip= ["วัน:O",'จำนวนผู้ป่วยในแต่ละวัน','สถานที่'],
     opacity=alt.condition(selection, alt.value(1), alt.value(0.2))).add_selection(
    selection
).properties(
    title='จำนวนผู้ติดเชื้อ COVID-19 ระหว่างวันที่ 12 มีนา 62 - 3เมษา 62 แบ่งตามสาเหตุและสถานที่'
)
    

chart2 = alt.Chart(df_3).mark_bar().encode(
    y="สถานที่:O",
    x= alt.X('จำนวนผู้ป่วยในแต่ละวัน',title = "จำนวนผู้ป่วย"),
    color=alt.Color('สถานที่:N', scale=alt.Scale(scheme='tableau20')),tooltip= ['จำนวนผู้ป่วยในแต่ละวัน','สถานที่','percent'],
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
    ).add_selection(
    selection
).properties(
    title='จำนวนผู้ติดเชื้อ COVID-19 ระหว่างวันที่ 12 มีนา 62 - 3เมษา 62 แบ่งตามสาเหตุและสถานที่'
)

chart3=alt.Chart(df_3).mark_bar().encode(
    y="สถานที่:O",
    x=alt.X('จำนวนผู้ป่วยในแต่ละวัน',title = "จำนวนผู้ป่วยเทียบเป็นเปอร์เซ็นต่อผู้ป่วยทั้งหมด"),
    color=alt.Color('สถานที่:N', scale=alt.Scale(scheme='tableau20')),tooltip= ['จำนวนผู้ป่วยในแต่ละวัน','สถานที่','percent'],
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
    ).add_selection(
    selection
).properties(
    title='จำนวนผู้ติดเชื้อ COVID-19 แบ่งตามสาเหตุและสถานที่เทียบเป็นเปอร์เซ็นของผู้ที่ได้รับเชื้อระหว่าวันที่  12 มีนา 62 - 3เมษา 62'
)

chart1|(chart2&chart3)
# Out:
# alt.HConcatChart(...)
